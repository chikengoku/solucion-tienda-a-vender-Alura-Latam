# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt



url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head(20)
# Out:
#                        Producto   Categoría del Producto     Precio  \
# 0             Asistente virtual             Electrónicos   164300.0
# 1               Mesa de comedor                  Muebles   192300.0
# 2                 Juego de mesa                 Juguetes   209600.0
# 3                    Microondas        Electrodomésticos   757500.0
# 4              Silla de oficina                  Muebles   335200.0
# 5       Bloques de construcción                 Juguetes    24200.0
# 6                   Muñeca bebé                 Juguetes    44200.0
# 7                  Lavavajillas        Electrodomésticos  1189700.0
# 8              Lavadora de ropa        Electrodomésticos  1518200.0
# 9     Carrito de control remoto                 Juguetes    75200.0
# 10                 Refrigerador        Electrodomésticos  2431300.0
# 11                 Lavavajillas        Electrodomésticos  1417100.0
# 12                  Auriculares             Electrónicos    91800.0
# ...

# %% [markdown]
# #Análisis de facturación
# ##Ingreso total por cada tienda
# por ejemplo para la primer tienda

# %%
tienda['Precio'].sum()
# Out:
# np.float64(1150880400.0)

# %% [markdown]
# Haciendo una tabla para cada precio total:
# Donde 1.150880e+09 =1,150,880,000

# %%
#total_ventas=pd.DataFrame({'ingreso_total':[tienda['Precio'].sum(),tienda2['Precio'].sum(),
 #                                           tienda3['Precio'].sum(),tienda4['Precio'].sum(),
 #                                          'tiendas':[tienda,tienda2,tienda3,tienda4]

total_ventas2=({'tienda':tienda['Precio'].sum(),'tienda2':tienda2['Precio'].sum(),
                'tienda3':tienda3['Precio'].sum(),'tienda4':tienda4['Precio'].sum() })
#total_ventas['ingreso_total']
# Out:
# 0    1.150880e+09
# 1    1.116344e+09
# 2    1.098020e+09
# 3    1.038376e+09
# Name: ingreso_total, dtype: float64

# %% [markdown]
# Para verlo en grafica
# *en la cual la **tienda 4** con indice 3 en la grafica presenta **menor**  precio en ventas*

# %%
ventas = pd.DataFrame.from_dict(total_ventas2, orient='index')
ventas.plot(kind='barh',xlabel='ingreso total *10⁹',title='Total de ventas segun precio ',color='green')
#total_ventas.plot(kind='line',xlabel='tiendas',ylabel='ingreso total *10⁹',color='red')
# Out:
# <Axes: title={'center': 'Total de ventas segun precio '}, xlabel='ingreso total *10⁹'>

# %%
ventas
# Out:
#                     0
# tienda   1.150880e+09
# tienda2  1.116344e+09
# tienda3  1.098020e+09
# tienda4  1.038376e+09

# %% [markdown]
# # 2. Ventas por categoría
# ##En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
tienda_ventascategoria=tienda['Categoría del Producto'].value_counts()
tienda_ventascategoria
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %% [markdown]
# ###por lo tanto para las demas tiendas:

# %%
tienda2_ventascategoria=tienda2['Categoría del Producto'].value_counts()
tienda3_ventascategoria=tienda3['Categoría del Producto'].value_counts()
tienda4_ventascategoria=tienda4['Categoría del Producto'].value_counts()

# %% [markdown]
# ##Con grafico de lineas

# %%
tienda_ventascategoria.plot(kind='line',figsize=(14,8),color='red')
tienda2_ventascategoria.plot(kind='line',figsize=(14,8),color='green')
tienda3_ventascategoria.plot(kind='line',figsize=(14,8),color='orange')
tienda4_ventascategoria.plot(kind='line',figsize=(14,8),color='black', title='Cantidad de ventas por categoria')
plt.legend(['tienda','tienda2','tienda3','tienda4'])
plt.grid()

# %% [markdown]
# # 3. Calificación promedio de la tienda
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %% [markdown]
# con este codigo vemos las cantidades de calificaciones que tuvieron

# %%
tienda['Calificación'].value_counts()
# Out:
# Calificación
# 5    1292
# 4     444
# 1     319
# 3     218
# 2      86
# Name: count, dtype: int64

# %% [markdown]
# Y para saber el promedio de estas

# %%
tienda['Calificación'].mean()
# Out:
# np.float64(3.976685036032217)

# %% [markdown]
# ##luego una tabla es de  promedio de cada tienda es :

# %%
promedios_tiendas=({'tienda_mean':tienda['Calificación'].mean(),'tienda2_mean':tienda2['Calificación'].mean(),'tienda3_mean':tienda3['Calificación'].mean(),'tienda4_mean':tienda4['Calificación'].mean()})

# %%
df = pd.DataFrame.from_dict(promedios_tiendas, orient='index')
df.plot(kind='line',title='Calificaciones promedio ')
plt.grid()

# %% [markdown]
# # 4. Productos más y menos vendidos
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
tiendapro=tienda['Producto'].value_counts()
tiendapro
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %% [markdown]
# ###los anteriores fueron todos los productos ahora seleccionare los 5 mejores y 5 peores

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Graficar las primeras 5 filas en el primer eje
tiendapro.head(10).plot(kind='bar', ax=ax1, title='Primeros 10 Productos',color='green')
ax1.set_xlabel('Ventas')
ax1.set_ylabel('Producto')

# Graficar las últimas 5 filas en el segundo eje
tiendapro.tail(10).plot(kind='bar', ax=ax2, title='Últimos 10 Productos', color='orange')
ax2.set_xlabel('Ventas')
ax2.set_ylabel('Producto')
# Out:
# Text(0, 0.5, 'Producto')

# %% [markdown]
# ##Tienda 2

# %%
tiendapro2=tienda2['Producto'].value_counts()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Graficar las primeras 5 filas en el primer eje
tiendapro2.head(10).plot(kind='bar', ax=ax1, title='Primeros 10 Productos',color='green')
ax1.set_xlabel('Ventas')
ax1.set_ylabel('Producto')

# Graficar las últimas 5 filas en el segundo eje
tiendapro2.tail(10).plot(kind='bar', ax=ax2, title='Últimos 10 Productos', color='orange')
ax2.set_xlabel('Ventas')
ax2.set_ylabel('Producto')
# Out:
# Text(0, 0.5, 'Producto')

# %% [markdown]
# ##Tienda 3

# %%
tiendapro3=tienda3['Producto'].value_counts()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Graficar las primeras 5 filas en el primer eje
tiendapro3.head(10).plot(kind='bar', ax=ax1, title='Primeros 10 Productos',color='green')
ax1.set_xlabel('Ventas')
ax1.set_ylabel('Producto')

# Graficar las últimas 5 filas en el segundo eje
tiendapro3.tail(10).plot(kind='bar', ax=ax2, title='Últimos 10 Productos', color='orange')
ax2.set_xlabel('Ventas')
ax2.set_ylabel('Producto')
# Out:
# Text(0, 0.5, 'Producto')

# %% [markdown]
# ##Tienda 4

# %%
tiendapro4=tienda4['Producto'].value_counts()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Graficar las primeras 5 filas en el primer eje
tiendapro4.head(10).plot(kind='bar', ax=ax1, title='Primeros 10 Productos',color='red')
ax1.set_xlabel('Ventas')
ax1.set_ylabel('Producto')

# Graficar las últimas 5 filas en el segundo eje
tiendapro4.tail(10).plot(kind='bar', ax=ax2, title='Últimos 10 Productos', color='orange')
ax2.set_xlabel('Ventas')
ax2.set_ylabel('Producto')
# Out:
# Text(0, 0.5, 'Producto')

# %% [markdown]
# # 5. Envío promedio por tienda
# ##En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %% [markdown]
# ###para esto

# %%
tienda['Costo de envío'].mean()
# Out:
# np.float64(26018.60958033065)

# %%
Costos_envio=({'tienda':tienda['Costo de envío'].mean(),'tienda2':tienda2['Costo de envío'].mean(),
              'tienda3':tienda3['Costo de envío'].mean(),
              'tienda4':tienda4['Costo de envío'].mean()})
df = pd.DataFrame.from_dict(Costos_envio, orient='index')
df.plot(kind='line',color='red',title='Costos_envio')
plt.grid()

# %%
Costos_envio
# Out:
# {'tienda': np.float64(26018.60958033065),
#  'tienda2': np.float64(25216.235693090293),
#  'tienda3': np.float64(24805.680373039424),
#  'tienda4': np.float64(23459.457167090754)}

# %% [markdown]
# #**Informe final**
# ##Con base en los análisis realizados y los gráficos generados, es momento de sintetizar sus hallazgos en un informe final. Dentro de tu Colab, deberás redactar un texto explicando a qué tienda debe vender el Sr. Juan, teniendo en cuenta todos los factores analizados, como:
#
#     Los ingresos totales de las tiendas.
#
#     Las categorías de productos más y menos vendidas.
#
#     Las calificaciones promedio de los clientes por tienda.
#
#     Los productos más y menos vendidos.
#
#     El coste de envío promedio para cada tienda.
#
# ##en su informe, incluya la justificación de su decisión, respaldada por el análisis y las visualizaciones que generó. Explicar, de forma clara y objetiva, las razones por las que una tienda destaca (o no) en relación a las demás, considerando las fortalezas y debilidades de cada una.
#
# ##Su informe debe estar bien estructurado, con una introducción que explique el propósito del análisis, un desarrollo con la presentación de datos y gráficos, y una conclusión recomendando la tienda que se debe vender y justificando la elección.

# %% [markdown]
# #**Introduccion**
#
#
# Desarrollare un analisis con los datos recolectados, para poder tomar decision, analisando cada grafica hecha, teniendo en cuenta que la tienda que prensenta menores ventas es la que presentaria mas posibilidad de ser vendida.
#
#
# ##Desarrollo
#
#
#
# 1.   deacuerdo ala columna de precios calculamos la tienda que se puede decir que tubo mayores ventas segun la grafica **Total de ventas segun precio** la **tienda 4** tiene menor ingreso
# 2. Con las **calificaciones promedio** la **tienda** tiene peor calificacion , la **tienda 4** es la siguiente pero con diferencia muy minima
# 3. Segun los productos mas vendidos podemos observar que la **Tienda** vende televisores mas 'caros' como el tv hd 4k
# electrodomestico no vendido en las otras tiendas, que segun la grafica **cantidad de ventas por categoria**  las tiendas venden mas electrodomesticos y muebles.
# 4.El coste de envio de cada tienda segun el grafico **costos_envio**  la **tienda4** tiene el menor costo y la que tiene mayor costo es la **tienda** pero teniedo en cuenta que en envio si es electrodomestico resulta ser mas caro.
#
# ##**Conclusion**
#
# ###segun lo visto al ser la **tienda4** al que menor ventas realiza no tener muy buena calificacion y no vender electrodomesticos como **neveras** que son de mayor valor o **tvhd**, como la **tienda** que tiene estos como sus productos mas vendidos,  resultaria mas viable **vender** la **tienda4**
